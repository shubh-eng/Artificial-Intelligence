# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh-eng/Artificial-Intelligence/blob/master/homework/HW_1082020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CHANGE MAKING

#!/bin/python

import math
import os
import random
import re
import sys

#
# Complete the 'getWays' function below.
#
# The function is expected to return a LONG_INTEGER.
# The function accepts following parameters:
#  1. INTEGER n
#  2. LONG_INTEGER_ARRAY c
#


    
def getWays(n, c):
    ways = [0] * (n + 1) 
    ways[0] = 1 
    for i in range(len(c)): 
        for j in range(len(ways)): 
            if (c[i] <= j): 
                ways[j] += ways[(int)(j - c[i])]
    return ways[n]
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = raw_input().rstrip().split()

    n = int(first_multiple_input[0])

    m = int(first_multiple_input[1])

    c = map(long, raw_input().rstrip().split())

    # Print the number of ways of making change for 'n' units using coins having the values given by 'c'

    ways = getWays(n, c)

    fptr.write(str(ways) + '\n')

    fptr.close()



## All possible sets where the elements equal the coins that add up to the change are calculated
## The total number of ways we can get the change is the sum of numbers of ways we can get change-coin1, change-coin2, change-coin3 and........change-coinN
##  ways[0] is initiated in the program with 1 as there is only one set in which we can give back change=0



#SHERLOCK AND COST

#!/bin/python

from __future__ import print_function

import os
import sys

# Complete the cost function below.
def cost(B):
    N = len(B)
    high,low=0,0
    for i in range(1,N): 
        high2low=abs(B[i-1] - 1)
        low2high=abs(B[i] - 1)
        low1=max(low, high+high2low)
        hi1=max(high, low+low2high)
        low=low1
        high=hi1
    return max (high,low)



if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(raw_input())

    for t_itr in xrange(t):
        n = int(raw_input())

        B = map(int, raw_input().rstrip().split())

        result = cost(B)

        fptr.write(str(result) + '\n')

    fptr.close()


''''
L(i) = maximised cost using first i items of array B, ending with 1 at i th position.
H(i) = maximised cost for first i items of array B, ending in Bi at i th position. 
F(i) = maximised cost for first i items regardless of ending.
L(i) = maximised (L(i-1),H(i-1)+|B(i-1) - 1|)
H(i) = maximised (H(i-1)+|B(i)-B(i-1)|,L(i-1)+|B(i) - 1|)
F(i) = maximised(L(i),H(i))


''''

#VALIDATING POSTAL CODES

regex_integer_in_range = r"_________"    # Do not delete 'r'.
regex_alternating_repetitive_digit_pair = r"_________"    # Do not delete 'r'.
regex_integer_in_range = r"^[1-9]\d{5}$"
regex_alternating_repetitive_digit_pair = r"(.)(?=.\1)"
